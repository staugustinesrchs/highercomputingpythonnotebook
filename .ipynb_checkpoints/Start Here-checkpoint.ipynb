# %% [markdown]
# # Higher Computing Science - Introduction to Python
#
# These interactive Python notebooks cover a brief introduction to Python.
#
# They are intended for students who already have a knowledge of another programming language at National 5 level.
#
# ## Notebooks
#
# 1. [Introduction to Python](Higher-Computing-Introduction-to-Python.ipynb)
# 2. [Variables](Higher-Computing-Python-Variables.ipynb)
# 3. [Loops](Higher-Computing-Loops.ipynb)
# 4. [Selection]()
# 5. [Pre-defined Functions (N5)](Higher-Computing-Pre-defined-Functions.ipynb)
#
#
# __Note__: the examples in these notebooks are not always written in the most efficient way. They are written to be clear and to illustrate how certain concepts work in Python.
